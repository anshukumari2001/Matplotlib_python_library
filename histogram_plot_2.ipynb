# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
ML_student_age=np.random.randint(18,46,(100))
Py_student_age=np.random.randint(10,38,(100))
print(ML_student_age)
print(Py_student_age)
# Out:
# [30 40 23 36 34 36 45 21 34 29 30 33 32 29 39 28 37 35 25 18 28 27 34 44
#  30 42 20 23 36 38 19 39 32 37 34 20 25 44 35 44 29 28 44 21 29 33 20 23
#  40 42 31 31 42 33 28 22 20 28 42 33 45 21 41 25 32 42 41 39 22 25 27 19
#  32 24 37 28 36 22 28 21 37 45 42 29 29 31 31 34 44 25 37 42 34 40 29 19
#  24 19 22 28]
# [19 24 34 18 36 17 16 35 17 35 30 20 13 24 22 22 12 19 29 25 32 25 25 25
#  12 34 17 18 17 35 27 30 13 31 26 33 15 11 15 18 11 36 31 30 36 16 17 28
#  12 26 14 35 32 13 26 20 32 35 23 23 37 12 14 14 33 16 20 30 27 33 22 24
#  33 35 12 15 36 10 23 36 37 13 14 24 19 28 33 25 28 17 34 11 10 19 30 10
#  30 18 16 10]

# %%
plt.hist(ML_student_age)
plt.title("ML_student_age")
plt.xlabel("Student_age")
plt.ylabel("Number of student")
plt.show()

# %%
from matplotlib import style
style.use("ggplot")
bins=[10,15,20,25,30,35,40,45]
plt.figure(figsize=(16,9))
plt.hist([ML_student_age,Py_student_age],bins,rwidth=0.8,color=['m','y'],orientation='vertical',label=['Ml_student','Py_student'])
plt.title("ML_student_age")
plt.xlabel("Student_age")
plt.ylabel("Number of student")
plt.grid(color='k',linestyle="-")
plt.legend(loc=4)
plt.show()
